# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from datetime import datetime
from collections import Counter
# import os

# %%
uber_apr = pd.read_csv('../input/uber-raw-data-apr14.csv')
uber_may = pd.read_csv('../input/uber-raw-data-may14.csv')
uber_jun = pd.read_csv('../input/uber-raw-data-jun14.csv')
uber_jul = pd.read_csv('../input/uber-raw-data-jul14.csv')
uber_aug = pd.read_csv('../input/uber-raw-data-aug14.csv')
uber_sep = pd.read_csv('../input/uber-raw-data-sep14.csv')

# %% [markdown]
# ### Plotting trips of for all 6 months:

# %%
all_dfs = [uber_apr, uber_may, uber_jun, uber_jul, uber_aug, uber_sep]
# all_dfs = [uber_apr, uber_may]
del uber_apr,uber_may, uber_jun, uber_jul, uber_aug, uber_sep

def get_trips(df_names):
    
    months_trips =  np.empty((31, 6))
    
    for ind, name in enumerate(df_names):
#         days = [datetime.strptime(pickup, '%m/%d/%Y %H:%M:%S').day for pickup in name['Date/Time']]        
        days = name['Date/Time'].apply(lambda pickup: datetime.strptime(pickup, '%m/%d/%Y %H:%M:%S').day)
        count_days = list(Counter(days).values())
        try:
            months_trips[:, ind] = count_days
        except:
            months_trips[0:-1, ind] = count_days
            months_trips[-1, ind] = np.nan
    
    return months_trips

months_trips = get_trips(all_dfs)

# %%
def plot_trips(trips_mat):    
    months = ['April', 'May', 'June', 'July', 'August', 'September']
    months_trips_df = pd.DataFrame(trips_mat, columns = months)

    fig, ax = plt.subplots(figsize = (14,14), ncols = 2, nrows = 3, sharey = True)
    mon = 0
    for row in range(3):
        for col in range(2):
            months_trips_df.iloc[:,mon].plot(ax = ax[row, col])
            ax[row,col].set_title('Uber-Trips: {} (2015)'.format(months[mon]), fontsize = 15)
            ax[row,col].axhline(y = np.mean(months_trips_df.iloc[:,mon]), linestyle = 'dashed',
                                color = 'g', alpha = 0.6, 
                                label = 'Mean: {}'.format(round(np.mean(months_trips_df.iloc[:,mon]),2)))
            ax[row,col].legend()

            mon+=1
    plt.show()
    
    return months_trips_df

months_trips_df = plot_trips(months_trips)

# %%
from pandas.plotting import autocorrelation_plot as acp
months = ['April', 'May', 'June', 'July', 'August', 'September']

fig, ax = plt.subplots(figsize = (16,16), ncols = 2, nrows = 3, sharey = True)
mon = 0
months_trips_df.fillna(0, inplace=True)
for row in range(3):
    for col in range(2):
        acp(months_trips_df.iloc[:,mon], ax = ax[row,col])
        ax[row,col].set_title('Auto-Correlation Plot: {}'.format(months[mon]), fontsize = 15)
        mon+=1

# %%
from statsmodels.graphics.tsaplots import plot_pacf
fig, ax = plt.subplots(figsize = (16,16), ncols = 2, nrows = 3, sharey = True)
mon = 0
for row in range(3):
    for col in range(2):
        plot_pacf(months_trips_df.iloc[:,mon], ax = ax[row,col], lags = 100)
        ax[row,col].set_title('Partial Auto-Correlation Plot: {}'.format(months[mon]), fontsize = 15)
        mon+=1
# Out:
# /opt/conda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Analysis with all the months combined:

# %%
all_uber_trips = [list(months_trips_df.iloc[:,i]) for i in range(6)]
all_uber_trips_2 = [count for trips in all_uber_trips for count in trips]
all_uber_trips_2 = [count for count in all_uber_trips_2 if count != 0]
len(all_uber_trips_2)
# Out:
# 183

# %%
fig, (ax1, ax2, ax3) = plt.subplots(figsize = (14,16), nrows = 3)
ax1.plot(all_uber_trips_2)
ax1.set_xlabel('Days (April to September)', fontsize = 15)
ax1.set_ylabel('#Trips per Day', fontsize = 15)
ax1.set_title('Uber-trips: April - September (2015)', fontsize = 20)

# fig, (ax1, ax2) = plt.subplots(figsize = (14,12), nrows = 2)
acp(all_uber_trips_2, ax = ax2)
ax2.set_title('Auto-Correlation', fontsize = 15)

plot_pacf(all_uber_trips_2, ax = ax3, lags = 400)
ax3.set_title('Partial Auto-Correlation', fontsize = 15)

plt.show()

# %% [markdown]
# ### +ve correlation at shor-term values  and -ve correlation at lon-term values.
# ### It's an indication of trend.
# ### So, we need to detrend the time-series before analysis.

# %%
all_trips_df = pd.DataFrame(all_uber_trips_2)
all_trips_df.columns = ['Trips']

# %%
r = all_trips_df.rolling(window = 10)

fig, ax = plt.subplots(figsize = (14,6))

all_trips_df['Trips'].plot(color = 'gray', ax = ax, label = 'Trips')
r.median()['Trips'].plot(color = 'red', ax = ax, label = 'Rolling Median')
r.mean()['Trips'].plot(color = 'green', ax = ax, label = 'Rolling Mean')
all_trips_df['Trips'].ewm(com = 0.8).mean().plot(ax = ax, color = 'black', linestyle = 'dashed', alpha = 0.6, label = 'EWMA')

ax.set_xlabel('Days (April - September)', fontsize = 15)
ax.set_ylabel('#Trips per Day', fontsize = 15)
ax.set_title('Increasing Trend of Rolling Mean and Median', fontsize = 20)
ax.legend()

plt.show()

# %% [markdown]
# ## Moving further with de-trending:

# %% [markdown]
# ### Following plot gives almost stationary (mean and variance) time-series:

# %%
log_all_trips_df = np.log(all_trips_df)
log_all_trips_df_diff = log_all_trips_df - log_all_trips_df.shift()

fig, ax = plt.subplots(figsize = (14, 6))
log_all_trips_df_diff.plot(ax = ax, color = 'k')
r2 = log_all_trips_df_diff.rolling(window = 30)
r2.mean()['Trips'].plot(color = 'red', ax = ax, label = 'Mean')
r2.std()['Trips'].plot(color = 'blue', ax = ax, label = 'STD')

# for i in range(7,175,7):
#     ax.axvline(x = i, linestyle = 'dashed', color = 'k', alpha = 0.5)

ax.legend()
plt.show()

# %% [markdown]
# ### Following plot helps in understanding the reason behind periodic spikes or the  internal structure.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(figsize = (14,14), nrows = 3)

log_all_trips_df_diff.fillna(0, inplace = True)
acp(log_all_trips_df_diff, ax = ax1)
for i in range(3,153,7):
    ax1.axvline(x = i, linestyle = 'dashed', color = 'k', alpha = 0.5)

acp(log_all_trips_df_diff, ax = ax2)
for i in range(7,177,7):
    ax2.axvline(x = i, linestyle = 'dashed', color = 'k', alpha = 0.5)

plot_pacf(log_all_trips_df_diff, ax = ax3, lags = 400)

plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
imp_stats = list(adfuller(log_all_trips_df_diff['Trips'], autolag = 'AIC', regression = 'c')[0:4])
values = ['Test-statistic', 'p-Value','#Lags', '#Obs.']
pd.DataFrame({'Stats': values, 
              'Values': imp_stats})
# Out:
#             Stats        Values
# 0  Test-statistic -6.683545e+00
# 1         p-Value  4.282167e-09
# 2           #Lags  1.100000e+01
# 3           #Obs.  1.710000e+02

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(np.array(log_all_trips_df_diff['Trips']), order = (2,1,0))
results_arima = model.fit(disp = -1)

fig, ax = plt.subplots(figsize = (14,6))
log_all_trips_df_diff.plot(ax = ax)
ax.plot(results_arima.fittedvalues, color = 'red')
ax.set_title('RSS: {}'.format(np.sum((results_arima.fittedvalues - log_all_trips_df_diff['Trips'][:-1])**2)))
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /opt/conda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /opt/conda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %% [markdown]
# ### Need to bring back the transformations (differencing and log) to actual values
# ### Try to understand the results of current analysis
# ### Segregate train and test data
# ### Repeat this analysis for Jan-June 2015

# %%
uber_jan_june = pd.read_csv('../input/uber-raw-data-janjune-15.csv')
print (uber_jan_june.head())
uber_jan_june.shape
# Out:
#   Dispatching_base_num          Pickup_date Affiliated_base_num  locationID
# 0               B02617  2015-05-17 09:47:00              B02617         141
# 1               B02617  2015-05-17 09:47:00              B02617          65
# 2               B02617  2015-05-17 09:47:00              B02617         100
# 3               B02617  2015-05-17 09:47:00              B02774          80
# 4               B02617  2015-05-17 09:47:00              B02617          90
# (14270479, 4)

# %%
uber_jan_june['Month_Day'] = uber_jan_june['Pickup_date'].apply(lambda pickup: datetime.strptime(pickup, '%Y-%m-%d %H:%M:%S').strftime('%m-%d').split('-'))

# %%
uber_jan_june['Month'] = [month_day [0] for month_day in uber_jan_june['Month_Day']]
uber_jan_june['Day'] = [month_day [1] for month_day in uber_jan_june['Month_Day']]
uber_jan_june.tail(20)
# Out:
#          Dispatching_base_num          Pickup_date Affiliated_base_num  \
# 14270459               B02765  2015-05-08 15:40:00              B02765
# 14270460               B02765  2015-05-08 15:41:00              B02764
# 14270461               B02765  2015-05-08 15:41:00              B02253
# 14270462               B02765  2015-05-08 15:41:00              B02682
# 14270463               B02765  2015-05-08 15:41:00              B02345
# 14270464               B02765  2015-05-08 15:41:00              B02765
# 14270465               B02765  2015-05-08 15:41:00              B02765
# 14270466               B02765  2015-05-08 15:41:00              B02765
# 14270467               B02765  2015-05-08 15:41:00              B02765
# 14270468               B02765  2015-05-08 15:42:00              B02096
# 14270469               B02765  2015-05-08 15:42:00              B02764
# 14270470               B02765  2015-05-08 15:42:00              B02765
# 14270471               B02765  2015-05-08 15:42:00              B02765
# 14270472               B02765  2015-05-08 15:42:00              B02765
# 14270473               B02765  2015-05-08 15:43:00              B02711
# 14270474               B02765  2015-05-08 15:43:00              B02765
# 14270475               B02765  2015-05-08 15:43:00              B02765
# 14270476               B02765  2015-05-08 15:43:00              B02765
# 14270477               B02765  2015-05-08 15:44:00              B01899
# 14270478               B02765  2015-05-08 15:44:00              B02682
#
#           locationID Month_Day Month Day
# 14270459         186  [05, 08]    05  08
# 14270460          50  [05, 08]    05  08
# 14270461          13  [05, 08]    05  08
# 14270462         192  [05, 08]    05  08
# 14270463         262  [05, 08]    05  08
# 14270464         237  [05, 08]    05  08
# 14270465         233  [05, 08]    05  08
# 14270466         148  [05, 08]    05  08
# 14270467          33  [05, 08]    05  08
# 14270468         232  [05, 08]    05  08
# 14270469          79  [05, 08]    05  08
# 14270470          37  [05, 08]    05  08
# 14270471         161  [05, 08]    05  08
# 14270472           7  [05, 08]    05  08
# 14270473          25  [05, 08]    05  08
# 14270474         186  [05, 08]    05  08
# 14270475         263  [05, 08]    05  08
# 14270476          90  [05, 08]    05  08
# 14270477          45  [05, 08]    05  08
# 14270478         144  [05, 08]    05  08

# %%
jan_june_grouped = uber_jan_june.groupby(by = ['Month', 'Day']).size().unstack()
jan_june_grouped
# Out:
# Day         01        02       03       04        05        06       07  \
# Month
# 01     58045.0   40287.0  59844.0  41943.0   43678.0   53539.0  63375.0
# 02     78592.0   70193.0  71532.0  68237.0   82336.0   87568.0  82752.0
# 03     70839.0   57460.0  75048.0  71931.0   77446.0   83134.0  81468.0
# 04     69223.0   74069.0  75983.0  69189.0   58357.0   53565.0  68079.0
# 05     92329.0  104978.0  80300.0  65447.0   76195.0   80447.0  87361.0
# 06     93499.0   97592.0  87206.0  95023.0  101922.0  101773.0  88876.0
#
# Day         08       09       10   ...          22       23       24  \
# Month                              ...
# 01     73016.0  72124.0  80656.0   ...     66819.0  73363.0  82588.0
# 02     64327.0  63306.0  66197.0   ...     67844.0  72494.0  80520.0
# 03     61824.0  53920.0  72185.0   ...     69337.0  60498.0  64400.0
# 04     72023.0  77520.0  81439.0   ...     82124.0  92110.0  99688.0
# 05     90733.0  98359.0  80146.0   ...     85771.0  78343.0  68328.0
# 06     76899.0  82463.0  87403.0   ...     75418.0  93172.0  91388.0
#
# Day          25       26        27       28       29        30       31
# Month
# 01      59382.0  44310.0   25954.0  61626.0  70441.0   85565.0  94448.0
# 02      75992.0  84840.0   90217.0  89716.0      NaN       NaN      NaN
# 03      73953.0  78552.0   84977.0  92527.0  75648.0   62780.0  78893.0
# 04     106270.0  88673.0   64783.0  68863.0  75940.0   84330.0      NaN
# 05      59748.0  72820.0   88662.0  95074.0  98200.0  104429.0  96947.0
# 06     100073.0  99508.0  136193.0  93108.0  74430.0   82627.0      NaN
#
# [6 rows x 31 columns]

# %%
all_jan_june = [jan_june_grouped.iloc[r,:] for r in range(jan_june_grouped.shape[0])]
all_jan_june = [trips for month in all_jan_june for trips in month]
len(all_jan_june)
# Out:
# 186

# %%
remove_inds = list(np.argwhere(np.isnan(all_jan_june) == True).reshape((1,5))[0])
all_jan_june_mod = [all_jan_june[i] for i,j in enumerate(all_jan_june) if i not in remove_inds]

# %%
print (len(all_jan_june_mod))
# Out:
# 181

# %%
fig, ax = plt.subplots(figsize = (14,6))
ax.plot(all_jan_june_mod)
ax.set_xlabel('Day of Month (Jan - June 2015)', fontsize = 15)
ax.set_ylabel('#Trips per Day', fontsize = 15)
ax.set_title('#Uber-Trips vs. Day of Month (Jan-Jun 2015)', fontsize = 20)
plt.show()

# %%
uber_jan_june_final = pd.DataFrame({'Days': range(1,len(all_jan_june_mod)+1), 'Trips': all_jan_june_mod})
uber_jan_june_final.head()
# uber_jan_june_final.to_csv('uber_jan_june_final', index=False)
# Out:
#    Days    Trips
# 0     1  58045.0
# 1     2  40287.0
# 2     3  59844.0
# 3     4  41943.0
# 4     5  43678.0

# %%
uber_jan_june_final['Trips_log'] = np.log(uber_jan_june_final['Trips'])
uber_jan_june_final['Shifted'] = uber_jan_june_final['Trips_log'] - uber_jan_june_final['Trips_log'].shift()
uber_jan_june_final.head()
# Out:
#    Days    Trips  Trips_log   Shifted
# 0     1  58045.0  10.968974       NaN
# 1     2  40287.0  10.603784 -0.365190
# 2     3  59844.0  10.999496  0.395712
# 3     4  41943.0  10.644067 -0.355430
# 4     5  43678.0  10.684600  0.040533

# %%
temp = uber_jan_june_final[['Shifted']][0:10]
temp.cumsum()
# Out:
#     Shifted
# 0       NaN
# 1 -0.365190
# 2  0.030523
# 3 -0.324907
# 4 -0.284374
# 5 -0.080808
# 6  0.087851
# 7  0.229460
# 8  0.217168
# 9  0.328975

# %%
fig, ax = plt.subplots(figsize = (14, 6))
uber_jan_june_final['Shifted'][1:].plot(ax = ax, color = 'k')
# r3 = uber_jan_june_final['Shifted'][1:].rolling(window = 30)
# r3.mean()['Shifted'].plot(color = 'red', ax = ax, label = 'Mean')
# r3.std()['Shifted'].plot(color = 'blue', ax = ax, label = 'STD')

# for i in range(7,175,7):
#     ax.axvline(x = i, linestyle = 'dashed', color = 'k', alpha = 0.5)

ax.legend()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(figsize = (14,14), nrows = 3)

uber_jan_june_final['Shifted'].fillna(0, inplace = True)
acp(uber_jan_june_final['Shifted'], ax = ax1)
# for i in range(3,153,7):
#     ax1.axvline(x = i, linestyle = 'dashed', color = 'k', alpha = 0.5)

acp(uber_jan_june_final['Shifted'], ax = ax2)
for i in range(7,177,7):
    ax2.axvline(x = i, linestyle = 'dashed', color = 'k', alpha = 0.5)

plot_pacf(uber_jan_june_final['Shifted'], ax = ax3, lags = 400)

plt.show()

# %%
# days_2015 = [datetime.strptime(pickup, '%m/%d/%Y %H:%M:%S').day for pickup in uber_jan_june['Date/Time']]        
# days_2015 = uber_jan_june['Pickup_date'].apply(lambda pickup: datetime.strptime(pickup, '%Y-%m-%d %H:%M:%S').day)

# count_days_2015 = list(Counter(days_2015).values())
# uber_jan_june = pd.DataFrame(list(dict(Counter(days_2015)).items()), columns = ['Day', 'Trips']).sort_values(by = 'Day').reset_index(drop = True)
# uber_jan_june

# %%
fig, (ax1, ax2, ax3) = plt.subplots(figsize = (14,6), nrows = 3)
ax1.plot(uber_jan_june['Trips'])
ax1.set_xlabel('Days (January to June)', fontsize = 15)
ax1.set_ylabel('#Trips per Day', fontsize = 15)
ax1.set_title('Uber-trips: April - September (2015)', fontsize = 20)

acp(uber_jan_june['Trips'], ax = ax2)
ax2.set_title('Auto-Correlation', fontsize = 15)

plot_pacf(uber_jan_june['Trips'], ax = ax3, lags = 400)
ax3.set_title('Partial Auto-Correlation', fontsize = 15)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Trips'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-60a3ff4f4256> in <module>()
#       1 fig, (ax1, ax2, ax3) = plt.subplots(figsize = (14,6), nrows = 3)
# ----> 2 ax1.plot(uber_jan_june['Trips'])
#       3 ax1.set_xlabel('Days (January to June)', fontsize = 15)
#       4 ax1.set_ylabel('#Trips per Day', fontsize = 15)
#       5 ax1.set_title('Uber-trips: April - September (2015)', fontsize = 20)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Trips'

# %% [markdown]
# ## Setting up LSTM:
# ### Data Pre-processing:

# %%
from sklearn.preprocessing import MinMaxScaler

## Split into train-test set:
train_jan_june = uber_jan_june_final.iloc[0:167,1:2].values
test_jan_june = uber_jan_june_final.iloc[167:,1:2].values

print ('Training data: ', train_jan_june.shape)
print ('Testing data: ', test_jan_june.shape)

## Feature-scaling:
mms = MinMaxScaler(feature_range = (0,1))
train_jan_june_scaled = mms.fit_transform(train_jan_june)
# Out:
# Training data:  (167, 1)
# Testing data:  (14, 1)

# %%
## Create structured training set:
x_train = []
y_train = []

for rides in range(14, 167):
    x_train.append(train_jan_june_scaled[rides-14:rides,0])
    y_train.append(train_jan_june_scaled[rides,0])
    
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, newshape = (x_train.shape[0], x_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Build RNN:

# %%
## units = 25, dropout = 0.1, optimizer = adam, epochs = 500
## units = 25, dropout = 0.1, optimizer = rmsprop, epochs = 500
## units = 40, dropout = 0.1, optimizer = adam, epochs = 500
## units = 40, dropout = 0.2, optimizer = adam, epochs = 500
## units = 40, dropout = 0.2, optimizer = adam, epochs = 500
## units = 40, dropout = 0.2, optimizer = adam, epochs = 500, batch_size = 16------best

# %%
np.random.seed(11)

# def grid_search_lstm():
regressor = Sequential()

## Adding first LSTM layer:
regressor.add(LSTM(units = 40, return_sequences = True, input_shape = (x_train.shape[1],1)))
regressor.add(Dropout(0.2))

## Adding second LSTM layer:
regressor.add(LSTM(units = 40, return_sequences = True))
regressor.add(Dropout(0.2))

## Adding third LSTM layer:
regressor.add(LSTM(units = 40, return_sequences = True))
regressor.add(Dropout(0.2))

## Adding fourth LSTM layer:
regressor.add(LSTM(units = 40, return_sequences = True))
regressor.add(Dropout(0.2))

## Adding fifth LSTM layer:
regressor.add(LSTM(units = 40, return_sequences = False))
regressor.add(Dropout(0.2))

## Adding o/p layer:
regressor.add(Dense(units = 1))

## Compiling RNN:
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

## Fitting RNN to training set:
regressor.fit(x = x_train, y = y_train, epochs = 1000, batch_size = 16)

#     return regressor

# parameters = {'batch_size': [32,64], 'epochs': [20,50,80,100], 'optimizer': ['adam', 'rmsprop']}
# Out:
# Epoch 1/1000
# 153/153 [==============================] - 18s 117ms/step - loss: 0.1987
# Epoch 2/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0432
# Epoch 3/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0361
# Epoch 4/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0250
# Epoch 5/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0267
# Epoch 6/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0249
# Epoch 7/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0267
# Epoch 8/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0222
# Epoch 9/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0236
# Epoch 10/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0236
# Epoch 11/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0239
# Epoch 12/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0239
# Epoch 13/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0233
# Epoch 14/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0244
# Epoch 15/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0234
# Epoch 16/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0235
# Epoch 17/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0245
# Epoch 18/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0223
# Epoch 19/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0226
# Epoch 20/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0228
# Epoch 21/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0227
# Epoch 22/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0225
# Epoch 23/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0242
# Epoch 24/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0234
# Epoch 25/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0182
# Epoch 26/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0194
# Epoch 27/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0211
# Epoch 28/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0236
# Epoch 29/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0225
# Epoch 30/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0207
# Epoch 31/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0239
# Epoch 32/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0216
# Epoch 33/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0218
# Epoch 34/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0212
# Epoch 35/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0212
# Epoch 36/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0212
# Epoch 37/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0212
# Epoch 38/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0241
# Epoch 39/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0225
# Epoch 40/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0231
# Epoch 41/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0268
# Epoch 42/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0210
# Epoch 43/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0218
# Epoch 44/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0227
# Epoch 45/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0234
# Epoch 46/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0221
# Epoch 47/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0210
# Epoch 48/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0198
# Epoch 49/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0210
# Epoch 50/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0192
# Epoch 51/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0178
# Epoch 52/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0205
# Epoch 53/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0205
# Epoch 54/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0213
# Epoch 55/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0193
# Epoch 56/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0188
# Epoch 57/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0215
# Epoch 58/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0307
# Epoch 59/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0212
# Epoch 60/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0200
# Epoch 61/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0212
# Epoch 62/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0209
# Epoch 63/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0207
# Epoch 64/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0208
# Epoch 65/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0192
# Epoch 66/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0206
# Epoch 67/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0209
# Epoch 68/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0228
# Epoch 69/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0206
# Epoch 70/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0207
# Epoch 71/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0198
# Epoch 72/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0203A: 0s - loss: 0.02
# Epoch 73/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0206
# Epoch 74/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0207
# Epoch 75/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0232
# Epoch 76/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0216
# Epoch 77/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0183
# Epoch 78/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0206
# Epoch 79/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0179
# Epoch 80/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0220
# Epoch 81/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0198
# Epoch 82/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0194
# Epoch 83/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0193
# Epoch 84/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0175
# Epoch 85/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0177
# Epoch 86/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0185
# Epoch 87/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0222
# Epoch 88/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0194
# Epoch 89/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0201
# Epoch 90/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0209
# Epoch 91/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0185
# Epoch 92/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0189
# Epoch 93/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0174
# Epoch 94/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0208
# Epoch 95/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0199
# Epoch 96/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0181
# Epoch 97/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0179
# Epoch 98/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0182
# Epoch 99/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0200
# Epoch 100/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0185
# Epoch 101/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0215
# Epoch 102/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0190
# Epoch 103/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0195
# Epoch 104/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0190
# Epoch 105/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0184
# Epoch 106/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0162
# Epoch 107/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0179
# Epoch 108/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0172
# Epoch 109/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0178
# Epoch 110/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0172
# Epoch 111/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0168
# Epoch 112/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0186
# Epoch 113/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0174
# Epoch 114/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0182
# Epoch 115/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0168
# Epoch 116/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0181
# Epoch 117/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0186
# Epoch 118/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0182
# Epoch 119/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0180
# Epoch 120/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0169
# Epoch 121/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0187A: 0s - loss: 0
# Epoch 122/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0180
# Epoch 123/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0171
# Epoch 124/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0187
# Epoch 125/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0169
# Epoch 126/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0203
# Epoch 127/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0193
# Epoch 128/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0191
# Epoch 129/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0171
# Epoch 130/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0181
# Epoch 131/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0173
# Epoch 132/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0158
# Epoch 133/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0177
# Epoch 134/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0170
# Epoch 135/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0179
# Epoch 136/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0174
# Epoch 137/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0163
# Epoch 138/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0181
# Epoch 139/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0187
# Epoch 140/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0180
# Epoch 141/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0173
# Epoch 142/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0177A: 0s - loss:
# Epoch 143/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0195
# Epoch 144/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0175
# Epoch 145/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0172
# Epoch 146/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0148
# Epoch 147/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0192
# Epoch 148/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0165
# Epoch 149/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0189
# Epoch 150/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0163
# Epoch 151/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0161
# Epoch 152/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0168
# Epoch 153/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0165
# Epoch 154/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0163
# Epoch 155/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0165
# Epoch 156/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0196
# Epoch 157/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0190
# Epoch 158/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0175
# Epoch 159/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0177
# Epoch 160/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0147
# Epoch 161/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0155
# Epoch 162/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0178
# Epoch 163/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0176
# Epoch 164/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0161
# Epoch 165/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0174
# Epoch 166/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0167
# Epoch 167/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0174
# Epoch 168/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0155
# Epoch 169/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0174
# Epoch 170/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0151
# Epoch 171/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0174
# Epoch 172/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0169
# Epoch 173/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0165
# Epoch 174/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0156
# Epoch 175/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0152
# Epoch 176/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0164
# Epoch 177/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0170
# Epoch 178/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0165
# Epoch 179/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0154
# Epoch 180/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0170
# Epoch 181/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0156
# Epoch 182/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0153
# Epoch 183/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0167
# Epoch 184/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0162
# Epoch 185/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0171
# Epoch 186/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0152
# Epoch 187/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0163
# Epoch 188/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0171
# Epoch 189/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0172
# Epoch 190/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0156
# Epoch 191/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0162
# Epoch 192/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0186
# Epoch 193/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0163
# Epoch 194/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0162
# Epoch 195/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0166
# Epoch 196/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0177
# Epoch 197/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0159
# Epoch 198/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0171
# Epoch 199/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0162
# Epoch 200/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0159
# Epoch 201/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0172
# Epoch 202/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0154
# Epoch 203/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0157
# Epoch 204/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0159
# Epoch 205/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0148
# Epoch 206/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0155
# Epoch 207/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0159
# Epoch 208/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0161
# Epoch 209/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0182
# Epoch 210/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0149
# Epoch 211/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0152
# Epoch 212/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0157
# Epoch 213/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0161
# Epoch 214/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0135
# Epoch 215/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0172
# Epoch 216/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0163
# Epoch 217/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0172
# Epoch 218/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0156
# Epoch 219/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0155
# Epoch 220/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0154
# Epoch 221/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0161
# Epoch 222/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0153
# Epoch 223/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0163
# Epoch 224/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0152
# Epoch 225/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0146
# Epoch 226/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0162
# Epoch 227/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0162
# Epoch 228/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0149
# Epoch 229/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0149
# Epoch 230/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0170
# Epoch 231/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0155
# Epoch 232/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0135
# Epoch 233/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0144
# Epoch 234/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0138
# Epoch 235/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0144
# Epoch 236/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0139
# Epoch 237/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0142
# Epoch 238/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0141
# Epoch 239/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0141
# Epoch 240/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0191
# Epoch 241/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0200
# Epoch 242/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0186
# Epoch 243/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0157
# Epoch 244/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0159
# Epoch 245/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0146
# Epoch 246/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0166
# Epoch 247/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0177
# Epoch 248/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0177
# Epoch 249/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0177
# Epoch 250/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0159
# Epoch 251/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0153
# Epoch 252/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0151
# Epoch 253/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0151
# Epoch 254/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0147
# Epoch 255/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0153
# Epoch 256/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0139
# Epoch 257/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0144
# Epoch 258/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0139
# Epoch 259/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0131
# Epoch 260/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0154
# Epoch 261/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0160
# Epoch 262/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0132
# Epoch 263/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0139
# Epoch 264/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0137
# Epoch 265/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0146
# Epoch 266/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0142
# Epoch 267/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0164
# Epoch 268/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0147
# Epoch 269/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0157
# Epoch 270/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0142
# Epoch 271/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0153
# Epoch 272/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0173
# Epoch 273/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0146
# Epoch 274/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0132
# Epoch 275/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0132
# Epoch 276/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0146
# Epoch 277/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0131
# Epoch 278/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0148
# Epoch 279/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0133
# Epoch 280/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0141
# Epoch 281/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0165
# Epoch 282/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0164
# Epoch 283/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0164
# Epoch 284/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0141
# Epoch 285/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0147
# Epoch 286/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0142
# Epoch 287/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0137
# Epoch 288/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0137
# Epoch 289/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0123
# Epoch 290/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0142
# Epoch 291/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0139
# Epoch 292/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0137
# Epoch 293/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0137
# Epoch 294/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0131
# Epoch 295/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0132
# Epoch 296/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0133
# Epoch 297/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0142
# Epoch 298/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0136
# Epoch 299/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0131
# Epoch 300/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0119
# Epoch 301/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0140
# Epoch 302/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0146
# Epoch 303/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0128
# Epoch 304/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0125
# Epoch 305/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0126
# Epoch 306/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0148
# Epoch 307/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0144
# Epoch 308/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0150
# Epoch 309/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0135
# Epoch 310/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0139
# Epoch 311/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0143
# Epoch 312/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0141
# Epoch 313/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0120
# Epoch 314/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0120
# Epoch 315/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0122
# Epoch 316/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 317/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0129
# Epoch 318/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 319/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0117
# Epoch 320/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0129
# Epoch 321/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0125
# Epoch 322/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0126
# Epoch 323/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0140
# Epoch 324/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 325/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0132A: 0s - loss:
# Epoch 326/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0120
# Epoch 327/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 328/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0128
# Epoch 329/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0135
# Epoch 330/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0129
# Epoch 331/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0113
# Epoch 332/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0125
# Epoch 333/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0133
# Epoch 334/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0130
# Epoch 335/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0129
# Epoch 336/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0138
# Epoch 337/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0132
# Epoch 338/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0129
# Epoch 339/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0125
# Epoch 340/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0131
# Epoch 341/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0136
# Epoch 342/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0128
# Epoch 343/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 344/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0130A: 0s - loss: 0.
# Epoch 345/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0131
# Epoch 346/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0126
# Epoch 347/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 348/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0130
# Epoch 349/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0129
# Epoch 350/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0126
# Epoch 351/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0117
# Epoch 352/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0114
# Epoch 353/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0120
# Epoch 354/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0120
# Epoch 355/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0119
# Epoch 356/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0127
# Epoch 357/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0115
# Epoch 358/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0131
# Epoch 359/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0127A: 0s - loss:
# Epoch 360/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0139
# Epoch 361/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 362/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 363/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 364/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 365/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0124
# Epoch 366/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0114
# Epoch 367/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0124
# Epoch 368/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0138
# Epoch 369/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0125
# Epoch 370/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0125
# Epoch 371/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 372/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0120
# Epoch 373/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0139
# Epoch 374/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 375/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0112
# Epoch 376/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0120
# Epoch 377/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0125
# Epoch 378/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0114
# Epoch 379/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 380/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0120
# Epoch 381/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0127
# Epoch 382/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0124
# Epoch 383/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0128
# Epoch 384/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0126
# Epoch 385/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 386/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0119
# Epoch 387/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0128
# Epoch 388/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0115
# Epoch 389/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 390/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0115
# Epoch 391/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0115
# Epoch 392/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0120
# Epoch 393/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 394/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 395/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0120
# Epoch 396/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0125
# Epoch 397/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0130
# Epoch 398/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0124
# Epoch 399/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0117
# Epoch 400/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0130
# Epoch 401/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0116A: 0s - loss: 0.01
# Epoch 402/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 403/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0120
# Epoch 404/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 405/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 406/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0104
# Epoch 407/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 408/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0120
# Epoch 409/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0112
# Epoch 410/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0124
# Epoch 411/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 412/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0112
# Epoch 413/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0113
# Epoch 414/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0120
# Epoch 415/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 416/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0126
# Epoch 417/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 418/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0112A: 0s - loss: 0.
# Epoch 419/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0115
# Epoch 420/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0119
# Epoch 421/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0122
# Epoch 422/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0120
# Epoch 423/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0122
# Epoch 424/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0114A: 0s - loss: 0.0
# Epoch 425/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0121
# Epoch 426/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 427/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 428/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 429/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0115
# Epoch 430/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0110
# Epoch 431/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0125
# Epoch 432/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0134
# Epoch 433/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0124
# Epoch 434/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0117
# Epoch 435/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 436/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0115
# Epoch 437/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0114
# Epoch 438/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0119
# Epoch 439/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0109
# Epoch 440/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 441/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0119
# Epoch 442/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0116
# Epoch 443/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0112
# Epoch 444/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0107
# Epoch 445/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 446/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0114
# Epoch 447/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 448/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0125
# Epoch 449/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 450/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0114
# Epoch 451/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0112
# Epoch 452/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0115
# Epoch 453/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0120
# Epoch 454/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0115
# Epoch 455/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 456/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0121
# Epoch 457/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0109
# Epoch 458/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0104
# Epoch 459/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0108
# Epoch 460/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0114
# Epoch 461/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 462/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0112
# Epoch 463/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0113
# Epoch 464/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0108
# Epoch 465/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0106
# Epoch 466/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0113
# Epoch 467/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 468/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0108
# Epoch 469/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 470/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 471/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 472/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0099
# Epoch 473/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0119
# Epoch 474/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0108
# Epoch 475/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0107
# Epoch 476/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0105
# Epoch 477/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 478/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0120
# Epoch 479/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0125
# Epoch 480/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0115
# Epoch 481/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0110
# Epoch 482/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0113
# Epoch 483/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0113
# Epoch 484/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0109
# Epoch 485/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0106
# Epoch 486/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0105
# Epoch 487/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0110
# Epoch 488/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0108
# Epoch 489/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0112
# Epoch 490/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 491/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0108
# Epoch 492/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0107
# Epoch 493/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0095
# Epoch 494/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0119
# Epoch 495/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 496/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0118A: 0s - loss: 0.0
# Epoch 497/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 498/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0108
# Epoch 499/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 500/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0117
# Epoch 501/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 502/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0117
# Epoch 503/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 504/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0130
# Epoch 505/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 506/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0115
# Epoch 507/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0119
# Epoch 508/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0115
# Epoch 509/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0104
# Epoch 510/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0111
# Epoch 511/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0114
# Epoch 512/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0131
# Epoch 513/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 514/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0100
# Epoch 515/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0113
# Epoch 516/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0108
# Epoch 517/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0106
# Epoch 518/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0101
# Epoch 519/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 520/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0108
# Epoch 521/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0108
# Epoch 522/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 523/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0112
# Epoch 524/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0109
# Epoch 525/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0109
# Epoch 526/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0106
# Epoch 527/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0110
# Epoch 528/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0121
# Epoch 529/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0106
# Epoch 530/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 531/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0114
# Epoch 532/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0106
# Epoch 533/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 534/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0126
# Epoch 535/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0107A: 0s - loss: 0.
# Epoch 536/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0117
# Epoch 537/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0110
# Epoch 538/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0108
# Epoch 539/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0113
# Epoch 540/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0111
# Epoch 541/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0101
# Epoch 542/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0105
# Epoch 543/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0116
# Epoch 544/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0103
# Epoch 545/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0101
# Epoch 546/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0118
# Epoch 547/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0109
# Epoch 548/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0109
# Epoch 549/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0102
# Epoch 550/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0110
# Epoch 551/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0106
# Epoch 552/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0117
# Epoch 553/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0144
# Epoch 554/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0123
# Epoch 555/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0121
# Epoch 556/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0111
# Epoch 557/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0107
# Epoch 558/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0097
# Epoch 559/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0104
# Epoch 560/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0097
# Epoch 561/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0107
# Epoch 562/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0116
# Epoch 563/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0121
# Epoch 564/1000
# ...
# Epoch 813/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0085
# Epoch 814/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0074
# Epoch 815/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0072
# Epoch 816/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0072
# Epoch 817/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0067
# Epoch 818/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0076
# Epoch 819/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0075
# Epoch 820/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0075
# Epoch 821/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0081
# Epoch 822/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0084
# Epoch 823/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0072
# Epoch 824/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0073
# Epoch 825/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0082
# Epoch 826/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0080
# Epoch 827/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0071
# Epoch 828/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0062
# Epoch 829/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0066
# Epoch 830/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0068
# Epoch 831/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0063
# Epoch 832/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0070
# Epoch 833/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0073
# Epoch 834/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0078
# Epoch 835/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0071
# Epoch 836/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0081
# Epoch 837/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0072
# Epoch 838/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0066
# Epoch 839/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0062
# Epoch 840/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0059
# Epoch 841/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0061
# Epoch 842/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0062
# Epoch 843/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0075
# Epoch 844/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0090
# Epoch 845/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0081
# Epoch 846/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0082
# Epoch 847/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0080
# Epoch 848/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0071
# Epoch 849/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0064
# Epoch 850/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0069
# Epoch 851/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0071
# Epoch 852/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0066
# Epoch 853/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0066
# Epoch 854/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0071
# Epoch 855/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0061
# Epoch 856/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0064
# Epoch 857/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0068
# Epoch 858/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0096
# Epoch 859/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0071
# Epoch 860/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0065
# Epoch 861/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0062
# Epoch 862/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0070
# Epoch 863/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0072
# Epoch 864/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0066
# Epoch 865/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0069
# Epoch 866/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0075
# Epoch 867/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0075
# Epoch 868/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0065
# Epoch 869/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0060
# Epoch 870/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0060
# Epoch 871/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0076
# Epoch 872/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0072
# Epoch 873/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0070
# Epoch 874/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0072
# Epoch 875/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0067
# Epoch 876/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0058
# Epoch 877/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0067
# Epoch 878/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0063
# Epoch 879/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0065
# Epoch 880/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0062
# Epoch 881/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0059
# Epoch 882/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0058
# Epoch 883/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0066
# Epoch 884/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0058
# Epoch 885/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0056
# Epoch 886/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0059
# Epoch 887/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0057
# Epoch 888/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0071
# Epoch 889/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0071
# Epoch 890/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0073
# Epoch 891/1000
# 153/153 [==============================] - 1s 8ms/step - loss: 0.0064
# Epoch 892/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0064
# Epoch 893/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0065
# Epoch 894/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0082
# Epoch 895/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0064
# Epoch 896/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0066
# Epoch 897/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0067
# Epoch 898/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0063
# Epoch 899/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0064
# Epoch 900/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0061
# Epoch 901/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0057
# Epoch 902/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0069
# Epoch 903/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0067
# Epoch 904/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0065
# Epoch 905/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0061
# Epoch 906/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0063
# Epoch 907/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0065
# Epoch 908/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0082
# Epoch 909/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0060
# Epoch 910/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0057
# Epoch 911/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0063
# Epoch 912/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0055
# Epoch 913/1000
# 153/153 [==============================] - 1s 8ms/step - loss: 0.0072
# Epoch 914/1000
# 153/153 [==============================] - 1s 8ms/step - loss: 0.0062
# Epoch 915/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0062
# Epoch 916/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0061
# Epoch 917/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0055
# Epoch 918/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0060
# Epoch 919/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0058
# Epoch 920/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0057
# Epoch 921/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0060
# Epoch 922/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0054
# Epoch 923/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0065
# Epoch 924/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0068
# Epoch 925/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0056
# Epoch 926/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0050
# Epoch 927/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0052
# Epoch 928/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0054
# Epoch 929/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0053
# Epoch 930/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0067
# Epoch 931/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0065
# Epoch 932/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0058
# Epoch 933/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0053
# Epoch 934/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0051
# Epoch 935/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0063
# Epoch 936/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0070
# Epoch 937/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0077
# Epoch 938/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0055
# Epoch 939/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0060
# Epoch 940/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0051
# Epoch 941/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0056
# Epoch 942/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0057
# Epoch 943/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0049
# Epoch 944/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0052
# Epoch 945/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0055
# Epoch 946/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0045
# Epoch 947/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0064
# Epoch 948/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0055
# Epoch 949/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0053
# Epoch 950/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0054
# Epoch 951/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0070
# Epoch 952/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0069
# Epoch 953/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0062
# Epoch 954/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0065
# Epoch 955/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0060
# Epoch 956/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0054
# Epoch 957/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0054
# Epoch 958/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0063
# Epoch 959/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0057
# Epoch 960/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0048
# Epoch 961/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0059
# Epoch 962/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0059
# Epoch 963/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0045
# Epoch 964/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0041A: 0s - loss: 0.004
# Epoch 965/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0049
# Epoch 966/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0048
# Epoch 967/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0056
# Epoch 968/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0065
# Epoch 969/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0059
# Epoch 970/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0056
# Epoch 971/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0050
# Epoch 972/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0058
# Epoch 973/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0052
# Epoch 974/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0046
# Epoch 975/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0050
# Epoch 976/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0051
# Epoch 977/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0056
# Epoch 978/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0069
# Epoch 979/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0049
# Epoch 980/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0041
# Epoch 981/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0053
# Epoch 982/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0045
# Epoch 983/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0047
# Epoch 984/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0045
# Epoch 985/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0047
# Epoch 986/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0052
# Epoch 987/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0055
# Epoch 988/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0044
# Epoch 989/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0048
# Epoch 990/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0042
# Epoch 991/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0050
# Epoch 992/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0051
# Epoch 993/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0057
# Epoch 994/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0059
# Epoch 995/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0055
# Epoch 996/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0050
# Epoch 997/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0070
# Epoch 998/1000
# 153/153 [==============================] - 1s 6ms/step - loss: 0.0064
# Epoch 999/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0053
# Epoch 1000/1000
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0049

# %%
adjusted_inputs = uber_jan_june_final[len(uber_jan_june_final) - len(test_jan_june) - 14:]['Trips'].values
adjusted_inputs = adjusted_inputs.reshape(-1,1)
adjusted_inputs = mms.transform(adjusted_inputs)
adjusted_inputs[0:10]
# Out:
# array([[0.64069119],
#        [0.72245641],
#        [0.79461942],
#        [0.79306089],
#        [0.65815926],
#        [0.53288077],
#        [0.59107978],
#        [0.6427518 ],
#        [0.79557127],
#        [0.80643913]])

# %%
x_test = []
for rides in range(14,29):
    x_test.append(adjusted_inputs[rides-14:rides,0])
    
x_test = np.array(x_test)
x_test = np.reshape(x_test, newshape = (x_test.shape[0], x_test.shape[1], 1))
x_test.shape
# Out:
# (15, 14, 1)

# %%
pred = regressor.predict(x_test)
pred = mms.inverse_transform(pred)
pred
# Out:
# array([[91238.17 ],
#        [93873.04 ],
#        [96351.41 ],
#        [99032.625],
#        [80483.35 ],
#        [82891.58 ],
#        [89860.58 ],
#        [92459.9  ],
#        [96966.73 ],
#        [97948.875],
#        [98681.16 ],
#        [93728.04 ],
#        [91810.84 ],
#        [92516.59 ],
#        [94171.07 ]], dtype=float32)

# %%
fig, ax = plt.subplots(figsize = (12,6))

e = [i*0.05 for i in pred]
ax.plot(pred, color = 'red', label = 'Predictions')
ax.errorbar(x = range(15), y = pred, yerr = e, fmt = '*', color = 'r')
ax.plot(test_jan_june, color = 'black', label = 'True')

ax.set_xlabel('Time-steps (Last two weeks of June-2015)', fontsize = 15)
ax.set_ylabel('#Uber trips', fontsize = 15)
ax.set_title('Comparing LSTM-predictions with True data', fontsize = 20)

ax.legend()
plt.show()

# %% [markdown]
# ## How to bring back the actual time-series (i.e. series before log transformation and differencing)

# %% [markdown]
# ## In this example ,it works: numbers are sorted

# %%
a = pd.DataFrame({'col1': [1,2,3,4]})
print(a)

a['log'] = np.log10(a)
print(a)

a['log_shifted'] = a['log'] - a['log'].shift()
print(a)

a['back_shift'] = a['log_shifted'].cumsum()
a
a['back_shift_antilog'] = pd.Series([10**i for i in a['back_shift']])
a

# %% [markdown]
# ## In this example, it doesn't work: Sorted but decreasing order
# ### Final reverse transformation is less by factor of 4 (see below)

# %%
a = pd.DataFrame({'col1': [4,3,2,1]})
print(a)

a['log'] = np.log10(a)
print(a)

a['log_shifted'] = a['log'] - a['log'].shift()
print(a)

a['back_shift'] = a['log_shifted'].cumsum()
a
a['back_shift_antilog'] = pd.Series([10**i for i in a['back_shift']])
a

# %% [markdown]
# ## In this example, numbers are random (i.e. something like real-world behavior)
# ### Behavior is still undesirable.

# %%
a = pd.DataFrame({'col1': [30,11,52,400]})
print(a)

a['log'] = np.log10(a)
print(a)

a['log_shifted'] = a['log'] - a['log'].shift()
print(a)

a['back_shift'] = a['log_shifted'].cumsum()
a
a['back_shift_antilog'] = pd.Series([10**i for i in a['back_shift']])
a

# %%
# from mpl_toolkits.basemap import Basemap
# plt.figure(figsize = (12,8))
# # m = Basemap(projection = 'mill', llcrnrlat= -90, llcrnrlon = -180, urcrnrlat = 90, urcrnrlon = 180, \
# #             resolution = 'i')

# m = Basemap(projection = 'mill', llcrnrlat= 20, llcrnrlon = -100, urcrnrlat = 50, urcrnrlon = -60, \
#             resolution = 'l')
# m.drawstates()
# m.drawcoastlines()
# m.fillcontinents()
# m.drawmapboundary()

# long, lat = uber_apr['Lon'], uber_apr['Lat']
# x, y = m(long, lat)
# m.plot(x, y, 'r.')
# plt.show()
